# %% [markdown]
# ## 자료형

# %%
# 문자열 자료형
#=========================================================
# escape code | \n 줄바꿈 | \t 탭 간격 | \\ \그대로 사용 | \' 그대로사용 | \" 그대로사용
#len 문자열 길이
#문자열[자료위치]  | 문자열 인덱싱(= 문자열 안의 특정한 값 뽑아냄)
#문자열[시작 번호(이상):끝 번호(미만)] | 문자열 슬라이싱(= 문자열 안의 특정한 범위의 값 뽑아냄)
#문자열의 요솟값은 바꿀 수 있는 값이 아니다. 슬라이싱을 이용해서 바꿔야함 ex) a = "pithon" > a[:1] + 'y' + a[2:] == python
#"~~ %d %s" |문자열 포맷팅 값 대입방법 | 2개이상일때는 "%s %s" % (a,b)로 표현
#문자열 포맷 코드  %s str | %d int | %c 문자 1개 | %f 부동소수 | %o 8진수 | %x 16진수 | %% 문자 그대로 사용 |
# %a.bs 는 s앞에 a만큼의 공백을 두고 b 번째 자리 소수점까지 나타낸다는 뜻. 물론 b는 %f인 경우에만 사용
# "~~~ {0} ~~".format(?) 숫자열 문자열 바로 대입 | {0}은 고정, ?은 s or f인경우 숫자, d인경우 ""형태로 작성
# => 숫자값, 문자로도 가능하며 2개이상도 가능 | a= 3 b= "three"라고 설정시 \n
#"I ate {0} apples. so I was sick for {1} days".format(a,b) 로 표현
#+ "I ate {a} apples. so I was sick for {b} days.".format(a=?1,b=?2)
#+ "I ate {0} apples. so I was sick for {b} days.".format(?1,b=?2)
#
#문자열 관련 함수 |
# 개수 세기 a.count(?) | 위치 알려주기 a.find or a.index | 문자열 삽입 "?".join('~~~~') ?을 사이에 삽입 | 소대문자 a.upper a.lower |
# 공백 지우기 a.rstrip or a.lstrip or a.strip | 문자열 바꾸기 a.replace(?1, ?2) ?1을 ?2로 치환 | 
# 문자열 나누기 a.split() 문자열을 list 형식으로 나눠서 보여줌 a.split('?')일 경우 ?를 기준으로 나눠줌

# %%
# 리스트 자료형 - list
#=========================================================
# 리스트 기본 구조 | 리스트 = [요소1, 요소2, 요소3, ....]
#
# 여러 리스트의 생김새 | 
# a=[] | b=[1,2,3] | c=['life', 'is', 'too', 'short'] | d=[1,2,'a','b'] | e=[1,2,['Life', 'is']] | a=list()
# 
# 리스트의 인덱싱 |
# a=[1,2,3] 일때, a[0] == 1 => a[0] + a[2] 등으로 사칙연산도 가능
# x=[1,2,3,['a', 'b', 'c']] 일때, a[0] == 1, a[-1 or 3] == ['a', 'b', 'c'], a[3][0] == 'a'
#
# 리스트의 슬라이싱 |
# a=[1,2,3,4, ...] a[슬라이싱할 번호] a[시작 번호:끝 번호] | 중첩 리스트 슬라이싱 a=[1,2,3,['a', 'b', 'c'], 4, 5] a[2:5] == [3,['a', 'b', 'c'], 4]
# 
# 리스트의 연산 |
# a=[1, 2, 3] b=[4, 5, 6] a+b == [1,2,3,4,5,6] | a*3 == [1, 2, 3, 1, 2, 3, 1, 2, 3]
# 리스트 길이 = len(리스트이름)
# 연산오류 잘 나오는 유형 = 형 오류 int 인지 str 인지 ex) a=[1, 2, 3] => a[2] + "hi" = 오류 => str(a[2]) + 'hi' = 3hi
# 
# 리스트의 수정과 삭제 |
# a=[1, 2, 3] | a[2] = 4 => a=[1, 2, 4] | del a[1] => a=[1, 3] | del a[1:] => a=[1] 
#
# 리스트 관련 함수들 |
# 요소추가 | a=[1, 2, 3] | a.append(4) => a=[1, 2, 3, 4] | a.append([4, 5]) => a=[1, 2, 3, [4, 5]]
#   정렬  | a=[1, 4, 3, 2] | a.sort() => a=[1, 2, 3, 4] 알파벳도 가능 | a.reverse() => a=[2, 3, 4, 1]
# 위치반환 | a=[1, 2, 3, 4] | a.index(요소) == 값:요소위치 if a.index(0)넣으면 오류
# 요소삽입 | a=[1, 2, 3] | a.insert(위치,요소) ex) a.index(2,7) => a=[1, 2, 7, 3]
# 요소제거 | a=[1, 2, 3, 1, 2, 3] | a.remove(?) 처음해당하는 ?을 제거 ex) a.remove(2) => a=[1, 3, 1, 2, 3]
# 위치설정 요소제거 | a=[1, 2, 3] | a.pop() 맨뒤요소 제거 => a=[1, 2] | a.pop(1) 요소위치 지정제거 => a=[1, 3]
# 요소 개수 측정 | a=[1, 2, 3, 1, 3] | a.count(1) ==2
# 확장 | a=[1, 2, 3] | a.extend([4, 5]) => a=[1, 2, 3, 4, 5] | b=[6, 7] a.extend(b) => a=[1, 2, 3, 6, 7]
# + insert는 하나의 요소를 위치지정해서 넣을 수 있음 | extend는 뒤에 여러개를 붙여서 넣을 수 있음
#
# 리스트의 복사 |
# a=[1, 2, 3] b= 일때 id(a) id(b) 를 통해 같은 값을 가르킴을 알 수 있음 =>  a를 바꾸면 b도 바뀜
# 복사시 값은 가져오지만 주소를 다르게 만드는 방법 |
# [:]이용 | a=[1, 2, 3] b= a[:] 하면 a를 바꿔도 b가 바뀌지 않는다
# copy이용 | b = copy(a) 시 위와 같은 효과

# %%
# 튜플 자료형 - t
#=========================================================
# 튜플은 값의 생성, 삭제, 수정이 불가능하다
# 튜플의 모습 | t1=() t2=(1,) t3=(1, 2, 3) t4=1, 2, 3 t5=('a', 'b', ('ab', 'bc')) => 노중첩 튜플은 괄호안써도 됨, 단일 요소 튜플은 t2처럼 요소뒤에 ,붙여야됨
# 튜플의 인덱싱/슬라이싱 | 리스트와 동일
# 튜플 연산 | t1=(1, 2, 'a', 'b') t2=(3, 4) | t1 + t2 == (1, 2, 'a', 'b', 3, 4) | t2*3 == (3, 4, 3, 4, 3 ,4) | len(t1) == 4

# %%
# 딕셔너리 자료형 - dic
#=========================================================
# 기본형 | dic = {key1: value1, key2: value2, ...} | 응용 a= {'a': [1, 2, 3]}
# 쌍 추가, 제거 | a={1: 'a'} | a[2] = 'b' => a={1: 'a', 2: 'b'} | del a[1] => a={} 키 제거시 밸류 자동삭제
# key 사용한 value 얻기 | grade={'pey': 10, 'julliet': 99} | grade('pey') == 10
# 사용시 유의점 | Value는 동일해도 되지만 key는 동일하면 안됨. ex) a={1: 'a', 1: 'b'} 는 오류. | Value에는 리스트를 사용가능, Key에는 불가능
# Key 리스트 만들기 | a={'name': 'pey', 'phone': '1234', 'birth': '0622'} | a.keys() == dict_keys(['name', 'phone', 'birth']) | list(a.keys()) == ['name', 'phone', 'birth']
# Value 리스트 만들기 | a.values() 위와 동일
# Key, Value 쌍 얻기 a.items() | 쌍 모두 지우기 a.clear() | Key로 Value 얻기 a.get(?) ?는 key | key가 안에 있는지 확인하기 key in a 있으면 True 없으면 False
# a.get(key)는 a.get(키,없을때의 디폴트값)으로 설정가능 => a.get('fck', 'not in ther')시 없으면 'not in ther' 출력
# 딕셔너리는 순서가 없는 자료형 이라 인덱싱을 지원하지 않는다.

# %%
# 집합 자료형 -set
#=========================================================
# 기본구조 | a= set([1, 2, 3]) => a=={1, 2, 3} | a= set('hello') => a=={'e', 'h', 'l', 'o'}
# 집합은 중복요소를 넣을 수 없다. 왜 why? 그것이 집합이니까.. 또한 순서가 없다. 왜 why? 그것이 어쩌구.. => 인덱싱을 지원하지 않는다.
# 집합을 인덱싱하기 위해서는? 리스트형으로 바꾸고 인덱싱하면 됨. ex) a= set([1, 2, 3]) => b=list(a) 이후 b를 인덱싱
# 교집합 s1 & s2 or s1.intersection(s2) | 합집합 s1 | s2 or s1.union(s2) | 차집합 s1 - s2 or s1.difference(s2)
# 값 1개 추가 s1.add(?) | 값 여러개 추가 s1.update([?, ?, ?]) | 특정 값 제거 s1.remove()

# %%
# 불 연산  - True, False
#=========================================================
# bool(?) ?에 따라 True False 나뉨. 아무것도 없으면 False 뭐가 있으면 True
# '?' = 참 | '' = 거짓 | [1, 2, 3] = 참 | [], (), {} = 거짓 | 1 = 참 | 0 = 거짓 | None = 거짓

# %% [markdown]
# ## 제어문

# %%
# if 문 - 참 거짓 판단
#=========================================================
# 기본구조 |
# if 조건문: -콜른(:) 필수
#   수행할 문장  - 들여쓰기 필수
# else:
#   수행할 문장
# 
# 비교 연산자 | > | < | == | != | >= | <=
#  조건 판단 | or 둘중 하나만 충족해도 참 | and 둘다 참이여야 참 | not ? ?가 거짓이면 참|
# in , not in | 'a' in ['a', 'b', 'c'] => True | 'a' not in ['a', 'b' ,'c'] => False | 리스트 튜플 문자열에 적용됨
# 조건부 표현식 | 조건문이 참인경우 if 조건문 else 조건문이 거짓인 경우
# if score >= 60: message = "success"
# else: message = "failure"
# => message= "success" if score >= 60 else "failure"

# %%
# while 문 - 문장 반복 수행
#=========================================================
# 기본구조 |
# while 조건문:
#   수행할 문장 - 조건이 참인 동안 반복 수행된다.
# while 문 강제 종료  break 사용 | while 문 처음으로 돌아가기 continue 사용

# %%
# for 문 - 
#=========================================================
# 기본구조 |
# (결과물 or 표현식) for 변수 in 리스트(튜플,문자열도 가능) (조건문):
#   수행할 문장
# 여기서도 continue 를 통해 결과값을 도출하지 않고 넘어갈 수 있다
#
# 자주 같이 쓰이는 range 함수|
# a= range(?) ==0이상 ?미만 | a=range(x,y) == x이상 y미만
#
# n중 for문 |
# 표현식 for 항목1 in 반복가능객체1 if 조건문1
#        for 항목2 in 반복가능객체2 if 조건문2

# %% [markdown]
# ## 입출력

# %%
# 함수
#=========================================================
# 기본 구조|
# def 함수명(매개변수1, 매개변수2, ..):
#   수행할 문장
#   return 결과값
#
# 입력할 매개변수가 몇 개 일지 모를 때 |
# def 함수명(*매개변수):
#   수행할 문장
# 매개변수 앞에 *를 붙이면 입력값을 전부 모아서 튜플로 만들어 준다.
#def add_mul(choice, *args):
#    if choice == "add":
#       result = 0
#      for i in args:
#            result = result + 1
#    elif choice == "mul":
#        result = 1
#        for i in args:
#            result =  result*i
#    return result
#  이런 식으로도 사용 가능
# 
# 키워드 파라미터 | kwargs - **붙여야함 | 딕셔너리 형태로 출력
# def t(**kwargs):
#   print(kwargs)
# 일때 t(a=1, name='foo') => {'a': 1m 'name': 'foo'} 로 출력.
#
# 함수의 결과값은 항상 하나 |
# def addmul(a,b):
#   return a+b, a*b
# 를 하면 result = addmul(3,4) => result =(7, 12)가 나옴 값이 여러개면 하나의 튜플로 묶여서 나온다.
# 만약 따로 결과값을 도출하고 싶다면 result1, result2 = addmul(3,  4) => result1, result2 = 7, 12 로 나온다.
# 함수는 return 문을 만나면 바로 탈출하기 때문에 return 문은 모든 함수의 끝에서 한 번만 쓴다.
# but 이 성질을 이용하여 강제 종료로 쓸 수 있다.
#
# 매개변수 초기값 설정 |
# def sm(name, old, man=True):
#   ~~~
# 이면 매개변수를 넣을 때 sm("박건호", 24)만 넣어도 man에는 초기 설정값인 True 가 적용된다. 
# but 초기 설정값은 맨 뒤 매개변수만 사용가능하며 중간에 있을 시 오류가 난다.
#
# 함수 안에서 선언한 변수의 효력 범위 |
# 함수 안에서의 변수는 함수 밖에서의 변수와 다르다. 함수 안에서의 변화를 통해 밖의 변수에 영향을 주기 위해서는 다음과 같은 명령어를 사용한다.
# return 을 통해 조건문을 통과한 변수의 결과를 다르게 나타낼 수 있다. | global을 통해 외부 변수를 직접적으로 사용할 수 있다. - 좋지않은 결과를 보일 수 있음
# lambda def와 동일한 역할을 한다. 함수를 한 줄로 표현할때 사용 ex) add = lambda a, b: a+b => add(a,b)로 사용

# %%
# 사용자 입력과 출력
#=========================================================
#
# 값을 어떤 변수에 대입하고 싶을 때 |
# a = input() 입력 숫자가 a에 대입됨
# a = input("입력하셈: ") 으로 활용도 가능 | 주의점 : input은 입력되는 모든 것을 str로 취급. 숫자로 쓰고 싶을때는 a = int(input()) 으로 사용
#
# print 자세히 알기 |
# "로 둘러싸인 문자열은 + 연산과 동일하다. | print("life" " is" " too short") == life is too short
# 문자열 띄어쓰기는 ,로 한다. | print("life", "is", "too short") = life is too short
# 한 줄에 결과값 입력하기 | 매개변수 end를 사용해 끝 문자를 지정한다.
# for i in range(10):
#   print(i, end=' ')

# %%
# 파일 읽고 쓰기
#=========================================================
#
# 파일 생성하기 |
# f = open("새파일.txt", 'w' or 'r' or 'a') | w = 쓰기모드 r=읽기모드 a=추가모드
# 절대 경로 설정 => "C:/smilegate/새파일.txt" 처럼 설정 가능
# 
# 파일을 w로 열어 출력값 적기 | - 새로운 파일을 만들어 쓰는 것, 기존에 있던 파일에 적용하면 다 날라감
# f = open("newfile.txt", 'w')
# for i in range(1,11):
#   data = "%d 번째 줄입니다." % i
#   f.write(data)
# f.close
# 처럼 f.write()를 통해 작성가능
#
# 외부 파일을 읽는 여러 방법 | readline, readlines, read
# readline 활용 | 첫 줄부터 읽음 2번실행 하면 2번째 줄
# f = open("newfile.txt", 'r')
# while True: - 그냥 반복하겠다는 뜻
#   line = f.readline() - line 에 readline 함수 넣음
#   if not line: break - 읽을 줄이 없으면 명령 종료
#   print(line)
# f.close - 파일을 읽고 나서는 닫아줘야함
#
# readlines 활용 | 파일의 모든 줄을 읽음
# f= open("newfile.txt", 'r')
#   lines = f.readlines()
#   for line in lines:
#       line=line.strip()  -- 줄 끝의 줄 바꿈 문자 제거
#       print(line)
# f.close()
#
# read 함수 사용 | 파일 내용 전체를 문자열로 돌려줌
# f= open("newfile.txt", 'r')
# data = f.read()
# print(data)
# f.close()
#
# 파일에 새로운 내용 추가하기 | 기존에 있던 파일에 내용을 추가하는 것
# f= open("oldfile.txt", 'a')
# for i in range(11, 20):
#   data = "%d 번째 줄입니다." % i
#   f.write(data)
# f.close
#
# with 문과 함께 사용하기 |
# with open("oldfile.txt", 'a') as f:
#   f.write("~~")
# => f.close 사용안해도 with 블록을 벗어나는 순간 자동으로 f.close가 적용된다.
#
# sys 모듈로 매개변수 주기 | 존나 어렵네 ㅅㅂ
# import sys
# args = sys.argv[1:]
# for i in argv:
#   print(i)

# %% [markdown]
# ## 클래스, 모듈, 패키지, 예외처리, 내장함수, 라이브러리

# %%
# 클래스
#=========================================================
# 틀(class)을 만들어 객체(object)를 찍어낼 수 있음
#  class cookie:
#      pass
#  이고 a= cookie() 이면 a는 객체, a는 cookie의 인스턴스 라고 표현 가능
#  
#  계산기 만들기 예제, 객체에 숫자 지정할 수 있게 만들기|
#class fourcal:
#    def setdata(self, first, second):
#        self.first = first
#        self.second = second
#    def add(self):
#        result = self.first + self.second
#        return result
# 이렇게 클래스 안에 구현된 def(함수)는 매서드(Method) 라고 한다.
# a = fourcal() 지정시 a.setdata(b, c)로 .을 사용해 클래스의 메서드를 호출 가능하다.
# ==> a.first = b / a.second = c
# ==> print(a.add())시 b+c의 결과값이 출력된다.
# 
# 생성자(condstructor)|
# 만약 위의 클래스에서 setdata를 하지않고 add를 진행하면 오류가 발생한다. 이렇게 객체에 초깃값을 설정해야 할 필요가 있을때 생성자를 구현한다.
# 생성자는 객체가 생성될 때 자동으로 호출되는 매서드를 의미한다.
# 
# 생성자 지정하기 __init__ |
# 위의 식에서 이를 추가하면 
#class fourcal:
#    def __init__(self,first,second):
#        self.first = first
#        self.second = seocond
#    def add(self):
#        result = self.first + self.second
#        return result
# ==> 이제는 setdata 함수가 필요없어 지고 a= fourcal(b,c)로 식을 실행해야한다. 
#
# 클래스의 상속|
# 다른 클래스의 기능을 물려받을 수 있게 된다. 앞의 코드에 더해서 작성해보면
# class morefourcal(fourcal):
#       pass
# 시 상속이 완료된다. 이제 a = morefourcal(b, c)로 사용이 가능하다.
# 이후 새로운 기능 추가시에는
# class morefourcal(fourcal):
#       def 새기능(self):
#           result = self.first 수식 self.second
#           return result
# 이런 식으로 이용이 가능하다.
#
# 매서드 오버라이딩|
# 덮어쓰기 기능이다. 예시로 작성해보면
# class safefourcal(fourcal):
#       def div(self):
#           if self.second == 0:
#               return 0
#           else: return self.first / self.second
# 이런식으로 덮어쓰기가 가능하다. 조건문이 없으면 zerodivison 오류가 나오기 때문에 덮어쓴것.
#
# 클래스 변수|
# 클래스 안에 함수를 선언하는 것처럼 클래스 안에 변수를 선언하여 생성한다. 클래스이름.클래스 변수로 사용가능하다.
# 클래스 변수는 클래스로 만든 모든 객체에 공유된다.

# %%
# 모듈 - 함수 혹은 변수 혹은 클래스를 모아 놓은 파일
#=========================================================
#
# 모듈 만들기|
# 함수를 작성하고 .py 형식으로 저장하면 된다.
#
# 모듈 불러오기|
# import 모듈명 => 이미 만들어 놓은 파이썬 모듈을 사용할 수 있게 해주는 명령어이다. => 모듈명.모듈함수(변수)
# 혹은 from 모듈이름 import 모듈함수1, 모듈함수2 를하면 모듈함수들을 바로 가져오므로 바로 사용가능하다. => 모듈함수(변수)
# 
# if__name__=="__main__": 의 의미|
# 만약 모듈내의 print가 있을 시 모듈을 import하는 것만으로 print가 되는 경우가 있다.
# 이런경우를 대비해 모듈 내에 
# if__name=="__main__":
#   print(함수(변수1,변수2)) 뭐 이런식으로 설정을 해놓으면
# 파일을 직접실행 시에는 참이되어 조건문이 실행되나 다른파일에서 모듈을 불러올때는 거짓이되어 조건문이 실행되지 않는다.
#
# 클래스나 변수 등을 포함한 모듈|
# 만약 한 모듈의 클래스 안에있는 함수를 사용하여 출력하고 싶다면
# 객체 = 모듈명.클래스() 이후 객체.함수(변수)로 사용한다.
# ex 
# hello.py 가
# pi = 3.14
# class math:
#   def solv(self,r):
#       return pi*(r**2) 이면
# import hello
# a=hello.math()
# print(a.solv(변수)) 이런식으로 사용한다. 클래스 안에 있는 함수가 아니라면 그냥 모듈명.함수(변수)로 사용가능

# %%
# 패키지 - 모듈의 계층적 관리
#=========================================================
# 만약 모듈이름이 A.B 이면 A는 패키지명, B는 A 패키지의 모듈이 된다.
# 파이썬 패키지는 디렉터리와 파이썬 모듈로 이루어진다.
#
# 이거 시발 뭔말이야

# %%
# 예외 처리
#=========================================================
# try, except|
# try:
#   ~~~~
# except [발생 오류[as 오류 메시지 변수]]:
#   ~~~~
# ==> try블록 실행 중 오류 발생시 except 블록 수행. 오류 발생 x시 except 블록 수행되지 않음
# 단일 except:만 사용시 오류 종류 상관없이 오류 발생시 except 수행    
# except 발생 오류: 시 except문에 미리 정해 놓은 오류 이름과 일치할 때만 except 수행 
# except 발생오류 as 오류 메시지 변수: 시 두 번째 경우에 더해 오류 메시지의 내용까지 출력
#
# try, finally|
# try문 수행 후 예외 발생 여부와 상관없이 finally문 실행
# ex)
# f=open('asdf.txt','w')
# try:
#   ~~
# finally:
#   f.close()
#
# 여러개의 오류처리하기|
# except를 여러개 사용하면 됨 혹은 except (발생오류1, 발생오류2) 로도 가능
# + else절 사용하기
# try:
#   ~~~
# except: - 오류 발생시 실행
#   ~~~~
# else:  - try에서 오류가 없을 시 실행
#   ~~~
#
# 오류 회피하기|
# except 문에서 pass사용
#
# 오류 킹부러 발생시키기|
# raise NotImplementedError - 구현이 안되면 오류발생
# ex) 
# class Bird:
#   def fly(self):
#       raise NotImplementedError
#
# class Eagle(Bird):
#   pass  ==> 오류 발생하게 됨 fly 함수를 구현하지 않았기 때문.
#   pass를 삭제하고 진행한다 생각하면
#   def fly(self):
#       print("aa")
#
# eagle= Eagle()
# eagle.fly() 이런식으로 작동하게 됨

# %%
# 내장 함수
#=========================================================
# 파이썬 내부에 구현돼있는 기본 함수들
# abs() 절대값 출력
# all() 변수 입력시 변수가 다 참이면 True, 거짓이 하나라도 있으면 False
# any() 변수중 하나라도 참이면 True 모두 거짓이면 False
# chr() 유니코드 값을 입력받아 문자 출력
# dir() 객체가 자체적으로 가지고있는 변수나 함수를 보여줌
# divmod(a, b) 두개의 숫자를 입력으로 받고 a를 b로 나눈 몫과 나머지를 튜플 형태로 출력 
# enumerate() 보통 for문과 같이 사용하며 순서가 있는 자료형을 입력으로 받아 열거하여 인덱스 값을 포함하는 객체로 돌려줌
# for i, name in enumerate(['body', 'foo', 'bar']):
#   print(i, name) 이런식으로 사용
# eval() 실행 가능한 문자열을 입력으로 받아 실행 결과값 돌려주는 함수
# eval('1+2') => 3 | eval('divmod(4,3)') => (1,1) 이런식 별로 쓸모 없어 보임
# filter(함수이름, 자료형) 첫 번째 인수로 함수 이름, 두 번째 인수로 그 함수에 차례로 들어갈 반복 가능한 자료형을 받고 두 번째 인수가 첫 번째 인수인 함수에 입력되었을 때 반환 값이 참인 것만 묶어서 돌려줌
# hex(정수) 정수 값을 입력받아 16진수로 변환하여 돌려줌
# id() 객체를 입력받아 고유 주소값 리턴
# input() 사용자 입력
# int() 문자열 형태의 숫자 혹은 소수점이 있는 숫자를 정수형으로 바꿔줌
# isinstance(object, class) 첫 인수가 클래스의 인스턴스가 맞으면 참 아니면 거짓
# len() 입력값의 길이(요소의 전체 개수)를 돌려줌
# list() 반복가능한 자료형을 리스트화
# map(f, iterable) 함수 f와 반복가능한 자료형을 입력으로 받음. 입력값의 f함수 수행결과 리턴 - 람다와 같이 사용하면 편할듯
# max() 자료형 입력받아 최댓값 리턴
# min() 최소값 리턴
# oct() 정수 형태의 숫자를 8진수 문자열로 리턴
# open(filename, mode) 파일을 모드를 선택해 열어줌
# ord() 문자의 유니코드 값을 돌려주는 함수 - chr 과 반대
# pow(a, b) a의 b제곱 리턴
# range(start,stop,step) 범위 값 리턴
# round(number, 보여줄 소수점 자리) 반올림 함수 뒷 인수 설정안할시 정수화
# sorted() 입력값 정렬 후 리턴 sort는 정렬만 하지만 sorted는 리턴값을 출력해서 보여줌
# str() 문자열 형태로 객체 변환
# sum() 더하기
# tuple() 튜플화해서 리턴
# type() 입력값의 자료형 출력
# zip() 동일한 개수로 이루어진 자료형을 묶어 주는 역할
# list(zip([1, 2, 3], [4, 5, 6]))
# => [(1, 4), (2, 5), (3, 6)]

# %%
# 라이브러리
#=========================================================
# sys 변수와 함수를 직접 제어|
# 명령 행에서 인수 전달 - sys.argv
# 강제로 스크립트 종료 - sys.exit()
# 모듈 저장 위치 - sys.path
#
# pickle - 객체의 형태 유지, 파일 저장/불러오기|
# f=open('~~.txt', 'wb') 와 pickle.dump(data, f) 를통해 data에 작성내용을 저장하고
# f=open('~~.txt', 'rb') 와 data=pickle.load(f) print(data)를 통해 불러올 수 있다.
#
# os - 환경 변수나 디렉터리, 파일등의 os 자원 제어가능|
# os.environ 내 시스템의 환경 변수값을 알고 싶을 때
# os.chdir(경로) 디렉터리 위치 변경하기
# os.getcwd() 현재 디렉터리 위치 리턴
# os.system("명령어") 시스템 명령어 호출
# os.popen("명령어") 시스템 명령어를 실행한 결과값
# f=os.popen("명령어") 식으로 사용
# os.mkdir(디렉터리) 디렉터리생성
# os.rmdir(디렉터리) 디렉터리 삭제. 단 비어있어야함
# os.unlink(파일) 파일삭제
# os.rename(a, b) 파일 a를 b로 이름 바꿈
#
# shutil - 파일 복사 모듈|
# shutil.copy("a.txt", "b.txt")
# a파일을 b로 복사. 만약 b가 디렉터리여도 가능. 동일한 파일 이름이 있을 경우에는 덮어씀
#
# glob 디렉터리에 있는 파일 리스트로 만듬|
# glob.glob(경로)
#
# tempfile 임시 파일|
# tempfile.mkstemp() 중복되지 않는 임시 파일의 이름을 무작위로 만듬
# f.close()시 자동으로 삭제됨
#
# time 시간 관련 모듈|
# time.time() UTC기준 현재 시 실수형태로 리턴
# time.localtime() 실수값을 연도,월,일,시,분,초 형태로 바꾸어 줌
# => time.localtime(time.time())으로 사용
# time.asctime() 위 튜플값을 쉽게 보게해줌 => time.asctime(time.localtime(time.time()))
# time.ctime == time.asctime(time.localtime(time.time()))
# asctime은 그냥 값을 변환해주고 ctime은 무조건 현재시만 나옴
# time.strftime('출력할 형식 포맷 코드', time.localtime(time.time()))
# 출력 형식 포맷 코드
# %a 요일 줄임말 / %A 요일 / %b 달 줄임말 / %B 달 / %c 날짜와 시간출력 / %d 날 / %H 시간(24시간기준)
# %I 시간(12시간기준) / %j 1년 중 누적 날짜 / %m 달 / %M 분 / %p AM orPM / %S 초 / %U 1년중 누적주(일시작)
# %w 숫자로 된 요일 / %W 1년중 누적주(월시작) / %x 현재 날짜 출력 / %X 현재 시간 출력 / %Y 년도출력
# %Z 시간대 출력 / %% 문자 / %y 세기부분 제외 년도 출력
# 
# time.sleep
# 루프안에서 많이 사용 일정한 시간 간격을 두고 루프 실행 가능
# ex)
# import time
# for i in range(10):
#   print(i)
#   time.sleep(1) = 1초간격으로 숫자 출력 실수 형태도 가능
# 
# calendar 달력 모듈
# calendar.calendar(연도) 그해 전체의 달력 출력 == calendar.prcal(연도)
# calendar.weekday(연도, 월, 일) 요일 정보 리턴 월화수목금토일 = 1234560
# calendar.monthrange(연도, 월) 입력받은 달의 1일이 무슨 요일인지 와 며칠까지 있는지 튜플로 리턴
# 
# random 난수 발생 모듈|
# random.random() 으로 사용
# random.randint(시작, 끝) 범위 내 정수 값으로 난수 리턴
# random.choice() 무작위 선택
# random.shuffle() 무작위로 섞기
#
# webbrowser 기본 웹 브라우저 실행|
# webbrowser.open(주소)
# webbrowser.open_new(주소)

# %% [markdown]
# ## 정규표현식

# %%
# 정규표현식
#===================================================================================================
#
# 문자클래스[] - [] 사이의 문자들과 매치
# - 은 범위를 나타냄 ^은 반대. 즉 ^0-9는 숫자가 있으면 매치안됨
# \d 숫자와 매치| \D 숫자가 아닌것과 매치| \s whitespace 문자와 매치| \S whitespace 문자가 아닌것과 매치
# \w 문자+숫자 매치| \W 문자+숫자가 아닌것과 매치
#
# Dot(.) 줄바꿈 문자인 \n을 제외한 모든 문자와 매치됨
# => a.b a와b사이에 어떤 문자가 들어가도 모두 매치. 없으면 매치안됨
# => a[.]b a.b와만 매치
# 
# 반복(*)
# ca*t 는 a가 0부터 무한대로 반복될 수 있다는 뜻
# 반복(+)
# *와 다르게 최소 1번 이상 반복될 때
# 반복({m,n},?)
# m번이상 n번이하 반복 ?는 {0,1}과 같은 의미
# 
# 정규 표현식 지원 re모듈
# import re
# re.compile(정규표현식)
#
# 정규식을 이용한 문자열 검색
# match() 문자열의 처음부터 정규식과 매치되는지 조사
# serch() 문자열 전체를 검색하여 정규식과 매치되는지 조사
# findall() 정규식과 매치되는 모든 문자열을 리스트로 돌려준다
# finditer() 정규식과 매치되는 모든 문자열을 반복 가능한 객체로 돌려준다
# 
# import re 
# p = re.compile('[a-z]+') 인 경우에서
